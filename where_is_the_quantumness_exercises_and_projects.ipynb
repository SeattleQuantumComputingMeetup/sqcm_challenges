# %% [markdown]
# # Thinking about Quantum Applications and Algorithms

# %% [markdown]
# ## Where Is the Quantumness in Quantum Computing?

# %% [markdown]
# <H2>QC References</H2>
#
# <a href=https://www.qisforquantum.org/>Q is for Quantum by Terry Rudolph (book)</a>
#
# <a href=https://pages.cs.wisc.edu/~jvangael/pubs/msthesis.pdf>The Role of Interference and Entanglement in Quantum Computing, by Jurgen Van Gael (MS thesis)</a>
#
# <a href=https://cs.uchicago.edu/news/uchicago-scientists-make-new-discovery-proving-entanglement-is-responsible-for-computational-hardness-in-quantum-systems/>Entanglement is Directly Responsible for Speedup in this Computational Problem, work by UChicago's Fefferman, et. al (article)</a>
#
# <a href=https://en.wikipedia.org/wiki/Quantum_Computation_and_Quantum_Information>Quantum Computation and Quantum Information, by Nielsen and Chuang (book)</a>
#
# <a href=https://www.oezratty.net/wordpress/2023/understanding-quantum-technologies-2023/>Understanding Quantum Technologies by Olivier Ezratty (book)</a>
#
# <a href=https://www.academia.edu/97932502/Quantum_Computing_for_Programmers>Quantum Computing for Programmers by Hundt (book)</a>
#
# <a href=https://medium.com/colibritd-quantum>ColibrITD blog</a>
#
# <a href=https://medium.com/@qiskit>Qiskit blog</a>
#
# <a href=https://www.xanadu.ai/blog/>Xanadu blog</a>
#
# <a href=https://learn.microsoft.com/en-us/azure/quantum/intro-to-resource-estimation>Azure Quantum Resource Estimator</a>
#
# <a href=https://arxiv.org/pdf/2211.07629.pdf>Assessing requirements to scale to practical quantum advantage</a>
#
# <a href=https://www.nature.com/articles/s41586-023-06096-3>Evidence for the utility of quantum computing before fault tolerance, IBM paper</a>
#
# <a href=https://arxiv.org/abs/quant-ph/0008033#>Addition on a Quantum Computer by Thomas Draper</a>
#
# <H2>QML References</H2>
#
# <a href=https://pennylane.ai/blog/2022/03/why-measuring-performance-is-our-biggest-blind-spot-in-quantum-machine-learning/>Why measuring performance is our biggest blind spot in quantum machine learning by Maria Schuld</a>
#
# <a href=https://arxiv.org/pdf/2203.01340.pdf>Is quantum advantage the right goal for quantum machine learning? by Schuld and Killoran</a>
#
#
# <H2>Online Edu References</H2>
#
# <a href=https://qiskit.org/learn>Qiskit Textbook</a>
#
# <a href=https://codebook.xanadu.ai/>Xanadu Codebook</a>

# %% [markdown]
# # Exercises and Projects
#
# How to get experience and practice?  Here are some things that you can do.  At the next meetup we can have a few presentations related to explorations suggested below.  You can try something, and let me know if you want to present, say for 5 mins, 10 mins, up to 15 mins.  I will review the proposals and decide the content for the next session.  You could write a medium article.  You can write some code.
#
# <H4>Edu Resources</H4> <br>
# If you like a particular online resource, present an example of it, demonstrate something that you like about it. <br>
# Present an example from the Xanadu Codebook. <br>
# Q-Ctrl has edu materials, such as Black Opal. <br>
# I am not sure what Quandela has, you could tell us.<br>
# IBM has a lot of Qiskit material.<br>
# MITRE has online materials, as does DeepLearningUniversity.
#
# <H4>Book Report of Sorts</H4> <br>
# Present in your own words the points made anywhere in the Q for Quantum book, possibly from the last chapter. <br>
# Find a section in the Nielsen and Chuang book that appeals to you and present it, this is the standard text. <br>
# And, anything similar.  The Hundt book is good for programmers.
# Ezratty has a lot of great content and diagrams in his book.
#
# <H4>Write some QC Code</H4> <br>
# Xanadu has some <a href=https://pennylane.ai/challenges/>Quantum Challenges</a> based on PennyLane <br>
# Write the Basic Arithmetic example shown tonight in your library of choice - Qiskit, Cirq, Q#, Braket.
#
# <H4>Interference, Superposition, and Entanglement</H4> <br>
# Read and present on work from the Van Gael thesis. <br>
# Read and present a medium blog post from ColibrITD or Qiskit, or from Xanadu's blog <br>
# Read and present the ideas and work in the UChicago Fefferman paper <br>
# Find a tutorial which relates to this topic and present it <br>
#
# <H4>Q Applications</H4> <br>
#
# Review the paper on "Addition on a QC" and present thoughts and details.
#
# <H4>Q Algorithms</H4> <br>
# Present ideas on how to write a new quantum algorithm <br> <br>
# <a href=https://web.cs.ucla.edu/~palsberg/>Jens Palsberg</a>, UCLA Computer Science prof commented at a UW QC Summit something along the lines that we should teach students how to create their own quantum algs rather than admire other people's.<br>
#
# Run Grover's algorithm on some use case and present it <br>
#
# Can AI be used to design quantum algorithms? <br>
#
# <H4>Computational Complexity Theory</H4> <br>
# Present the state of affairs for quantum and classical <br>
# Possibly consider the Traveling Salesperson problem classically and quantumly <br>
# Describe the difference between Quantum Advantage and Quantum Utility <br>
# Present ideas from IBM's Quantum Utility paper <br>
#
# <H4>QML</H4> <br>
# Present the ideas in the Maria Schuld references above <br>
#
# <H4>Resource Estimation</H4> <br>
# Use the resource estimator in Azure Quantum to estimate resources needed for some problem. <br>
# There are tutorials included, maybe just present one of those as a starting point.  <br><br>
# Check out MSFT's paper on quantum resource estimation, and present some element of it. <br>
#
# <H4>Open Ended</H4>
#
# Have another idea, try that! <br>
# Quantum Benchmarks, Details about Qubits, Compare Qubits <br>
# Create a Quantum Game to explore I-S-E <br>
