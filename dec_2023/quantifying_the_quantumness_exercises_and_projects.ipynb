# %% [markdown]
# # Thinking about Quantum Applications and Algorithms, Part 2

# %% [markdown]
# ## Quantifying the Quantumness in Quantum Computing?

# %% [markdown]
# <H2>QC References</H2>
#
# <a href=https://www.quantamagazine.org/the-quest-to-quantify-quantumness-20231019/>The Quest to Quantify Quantumness, Quanta Magazine, Charlie Wood</a>
#
# <a href=https://arxiv.org/pdf/2212.10582.pdf>Sharp complexity phase transitions generated by entanglement, Fefferman, et al</a>
#
# <a href=https://www.scottaaronson.com/writings/qchallenge.html>Ten Semi-Grand Challenges for Quantum Computing Theory</a>
#
#
# <H2>QML References</H2>
#
# <a href=https://iopscience.iop.org/article/10.1088/1367-2630/abac39/pdf>Key Questions for the quantum machine learner to ask themselves, Nathan Wiebe, Sep 2020</a>
#
# <H2>Quantum Algorithms References</H2>
#
# <a href=https://www.youtube.com/watch?v=TPHlIZ0VoJE>The Quantum Algorithm Tier List, PennyLane, Isaac and Guillermo</a>
#
# <H2>Quantum Applications References</H2>
#
# <a href=https://www.youtube.com/watch?v=87qToGgviDA>The Future of Chemistry is Self-Driving, Alán Aspuru-Guzik</a>

# %% [markdown]
# # Exercises and Projects
#
# How to get experience and practice?  Here are some things that you can do.  At the next meetup we can have a few presentations related to explorations suggested below.  You can try something, and let me know if you want to present, say for 5 mins, 10 mins, up to 15 mins.  I will review the proposals and decide the content for the next session.  You could write a medium article.  You can write some code.
#
# <H4>Quantifying the Quantumness</H4>
#
# Select one of the three quantum resources mentioned in "The Quest to Quantify Quantumness" article above, find work by the researchers mentioned, present the details <br><br>
# Report on the 10 Semi-Grand Challenges for Quantum Computing that Scott Aaronson identified, Jul 2005 <br>
#
# <H4>QML</H4>
#
# Answer the Question, What is QML? <br>
#
# <H4>Quantum Algorithms</H4>
#
# Report on the content in the PennyLane video referenced above.  Optionally, find other resources to add to the content.
#
# <H4>Quantum Applications</H4>
#
# Report on the content in the Alan Aspuru-Guzik interview above about self-driving labs in chemistry.
#
# <H4>Choose your own topic</H4>
#
# Have an interest not mentioned?  Explore that!
